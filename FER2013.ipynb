# %% [markdown]
# #Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #Import Libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras.models import Sequential #Initialise our neural network model as a sequential network
from keras.layers import Conv2D #Convolution operation
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.layers import Activation#Applies activation function
from keras.layers import Dropout#Prevents overfitting by randomly converting few outputs to zero
from keras.layers import MaxPooling2D # Maxpooling function
from keras.layers import Flatten # Converting 2D arrays into a 1D linear vector
from keras.layers import Dense # Regular fully connected neural network
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, TensorBoard, ModelCheckpoint
from sklearn.metrics import accuracy_score

# %% [markdown]
# #Define Data Loading Mechanism

# %%
def load_data(dataset_path):
  
  #classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprsie', 'Neutral']  #We will be dealing with seven different types of emotions.

  data = []
  test_data = []
  test_labels = []
  labels =[]

  with open(dataset_path, 'r') as file:
      for line_no, line in enumerate(file.readlines()):
          if 0 < line_no <= 35887:
            curr_class, line, set_type = line.split(',')
            image_data = np.asarray([int(x) for x in line.split()]).reshape(48, 48)#Creating a list out of the string then converting it into a 2-Dimensional numpy array.
            image_data =image_data.astype(np.uint8)/255.0
            
            if (set_type.strip() == 'PrivateTest'):
              
              test_data.append(image_data)
              test_labels.append(curr_class)
            else:
              data.append(image_data)
              labels.append(curr_class)
      
      test_data = np.expand_dims(test_data, -1)
      test_labels = to_categorical(test_labels, num_classes = 7)
      data = np.expand_dims(data, -1)   
      labels = to_categorical(labels, num_classes = 7)
    
      return np.array(data), np.array(labels), np.array(test_data), np.array(test_labels)

# %% [markdown]
# #Load the Data

# %%
dataset_path = "/content/gdrive/My Drive/DataSets/FER2013/Original/fer2013.csv" 
train_data, train_labels, test_data, test_labels = load_data(dataset_path)
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size = test_size,random_state = seed)

print("Number of images in Training set:", train_data.shape)
print("Number of images in Test set:", test_data.shape)
# Out:
# Number of images in Training set: (32298, 48, 48, 1)
# Number of images in Test set: (3589, 48, 48, 1)

# %% [markdown]
# #Define and Deploy the Neural Network
# Callback functions are those functions which are called at the end of every epoch and in this model, we use two callback functions - ReduceLROnPlateau and EarlyStopping.
#
# 1. **ReduceLROnPlateau**: monitors a certain variable, in this case, validation loss and alters the learning rate when the value stops significantly changing after some certain number of epochs (patience).
#
# 2. **EarlyStopping:** At times our optimiser can land in local optima and get stuck there. There is no point in continuing the training as there won't be any further improvements.
#
# 3. **ModelCheckpoint:** Saves the best version of our model along with the weights, so that in case any crash occurs, our model can be recovered.
#
#
# We have used Keras to deploy our neural network and if you look at the architecture then you will notice that we have used Dropout layers frequently. Dropout layers inhibit overfitting by randomly dropping out units from the neural network. We will use 20 percent of the training data as validation data.

# %%
epochs = 100
batch_size = 64
learning_rate = 0.001

model = Sequential()
    
model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1), kernel_regularizer=l2(0.01)))
model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
adam = optimizers.Adam(lr = learning_rate)
model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
print(model.summary())

lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3)
early_stopper = EarlyStopping(monitor='val_acc', min_delta=0, patience=6, mode='auto')
checkpointer = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5', monitor='val_loss', verbose=1, save_best_only=True)

model.fit(
          train_data,
          train_labels,
          epochs = epochs,
          batch_size = batch_size,
          validation_split = 0.2,
          shuffle = True,
          callbacks=[lr_reducer, checkpointer, early_stopper]
          )
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_64 (Conv2D)           (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_65 (Conv2D)           (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_67 (Conv2D)           (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_71 (Conv2D)           (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_65 (Batc (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_72 (Conv2D)           (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_66 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_73 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_67 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_68 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 7)                 455
# =================================================================
# Total params: 9,014,727
# Trainable params: 9,009,223
# Non-trainable params: 5,504
# _________________________________________________________________
# None
# Epoch 1/100
# 404/404 [==============================] - 27s 64ms/step - loss: 2.4772 - accuracy: 0.1825 - val_loss: 1.8444 - val_accuracy: 0.2489
#
# Epoch 00001: val_loss improved from inf to 1.84440, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 2/100
# 404/404 [==============================] - 26s 64ms/step - loss: 1.8717 - accuracy: 0.2350 - val_loss: 1.8384 - val_accuracy: 0.2489
#
# Epoch 00002: val_loss improved from 1.84440 to 1.83837, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 3/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.8412 - accuracy: 0.2524 - val_loss: 1.8264 - val_accuracy: 0.2489
#
# Epoch 00003: val_loss improved from 1.83837 to 1.82638, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 4/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.8366 - accuracy: 0.2486 - val_loss: 1.8187 - val_accuracy: 0.2489
#
# Epoch 00004: val_loss improved from 1.82638 to 1.81873, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 5/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.8239 - accuracy: 0.2504 - val_loss: 1.8141 - val_accuracy: 0.2491
#
# Epoch 00005: val_loss improved from 1.81873 to 1.81405, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 6/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.8197 - accuracy: 0.2533 - val_loss: 1.8106 - val_accuracy: 0.2489
#
# Epoch 00006: val_loss improved from 1.81405 to 1.81062, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 7/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.8106 - accuracy: 0.2550 - val_loss: 1.8018 - val_accuracy: 0.2494
#
# Epoch 00007: val_loss improved from 1.81062 to 1.80178, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 8/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.8018 - accuracy: 0.2520 - val_loss: 1.8011 - val_accuracy: 0.2511
#
# Epoch 00008: val_loss improved from 1.80178 to 1.80109, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 9/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.7982 - accuracy: 0.2526 - val_loss: 1.8011 - val_accuracy: 0.2489
#
# Epoch 00009: val_loss did not improve from 1.80109
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 10/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.7818 - accuracy: 0.2658 - val_loss: 1.7417 - val_accuracy: 0.3008
#
# Epoch 00010: val_loss improved from 1.80109 to 1.74174, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 11/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.7532 - accuracy: 0.2847 - val_loss: 2.0940 - val_accuracy: 0.2492
#
# Epoch 00011: val_loss did not improve from 1.74174
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 12/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.7046 - accuracy: 0.2978 - val_loss: 1.5527 - val_accuracy: 0.3704
#
# Epoch 00012: val_loss improved from 1.74174 to 1.55272, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 13/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.6311 - accuracy: 0.3394 - val_loss: 1.5196 - val_accuracy: 0.4034
#
# Epoch 00013: val_loss improved from 1.55272 to 1.51965, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 14/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.5705 - accuracy: 0.3739 - val_loss: 1.4592 - val_accuracy: 0.4170
#
# Epoch 00014: val_loss improved from 1.51965 to 1.45916, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 15/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.5538 - accuracy: 0.3876 - val_loss: 1.4829 - val_accuracy: 0.3995
#
# Epoch 00015: val_loss did not improve from 1.45916
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 16/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.5183 - accuracy: 0.3949 - val_loss: 1.5751 - val_accuracy: 0.3610
#
# Epoch 00016: val_loss did not improve from 1.45916
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 17/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.4797 - accuracy: 0.4123 - val_loss: 1.3871 - val_accuracy: 0.4288
#
# Epoch 00017: val_loss improved from 1.45916 to 1.38712, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 18/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.4726 - accuracy: 0.4143 - val_loss: 1.3740 - val_accuracy: 0.4444
#
# Epoch 00018: val_loss improved from 1.38712 to 1.37396, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 19/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.4468 - accuracy: 0.4255 - val_loss: 1.3290 - val_accuracy: 0.4455
#
# Epoch 00019: val_loss improved from 1.37396 to 1.32900, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 20/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.4087 - accuracy: 0.4361 - val_loss: 1.3843 - val_accuracy: 0.4396
#
# Epoch 00020: val_loss did not improve from 1.32900
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 21/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.4079 - accuracy: 0.4370 - val_loss: 1.4832 - val_accuracy: 0.3969
#
# Epoch 00021: val_loss did not improve from 1.32900
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 22/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.3872 - accuracy: 0.4444 - val_loss: 1.4261 - val_accuracy: 0.4068
#
# Epoch 00022: val_loss did not improve from 1.32900
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 23/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.3703 - accuracy: 0.4463 - val_loss: 1.3700 - val_accuracy: 0.4415
#
# Epoch 00023: val_loss did not improve from 1.32900
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 24/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.3371 - accuracy: 0.4589 - val_loss: 1.3379 - val_accuracy: 0.4666
#
# Epoch 00024: val_loss did not improve from 1.32900
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 25/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.3197 - accuracy: 0.4667 - val_loss: 1.2927 - val_accuracy: 0.4949
#
# Epoch 00025: val_loss improved from 1.32900 to 1.29269, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 26/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.3127 - accuracy: 0.4725 - val_loss: 1.2779 - val_accuracy: 0.4912
#
# Epoch 00026: val_loss improved from 1.29269 to 1.27788, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 27/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.2740 - accuracy: 0.4913 - val_loss: 1.2548 - val_accuracy: 0.5029
#
# Epoch 00027: val_loss improved from 1.27788 to 1.25485, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 28/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.2829 - accuracy: 0.4913 - val_loss: 1.2522 - val_accuracy: 0.5163
#
# Epoch 00028: val_loss improved from 1.25485 to 1.25217, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 29/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.2693 - accuracy: 0.4998 - val_loss: 1.3475 - val_accuracy: 0.4661
#
# Epoch 00029: val_loss did not improve from 1.25217
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 30/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.2217 - accuracy: 0.5229 - val_loss: 1.2367 - val_accuracy: 0.5432
#
# Epoch 00030: val_loss improved from 1.25217 to 1.23665, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 31/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.2120 - accuracy: 0.5327 - val_loss: 1.2546 - val_accuracy: 0.5189
#
# Epoch 00031: val_loss did not improve from 1.23665
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 32/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.1970 - accuracy: 0.5435 - val_loss: 1.2346 - val_accuracy: 0.5224
#
# Epoch 00032: val_loss improved from 1.23665 to 1.23456, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 33/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.1616 - accuracy: 0.5580 - val_loss: 1.2118 - val_accuracy: 0.5444
#
# Epoch 00033: val_loss improved from 1.23456 to 1.21181, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 34/100
# 404/404 [==============================] - 26s 63ms/step - loss: 1.1347 - accuracy: 0.5751 - val_loss: 1.1861 - val_accuracy: 0.5590
#
# Epoch 00034: val_loss improved from 1.21181 to 1.18606, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 35/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.1198 - accuracy: 0.5713 - val_loss: 1.2065 - val_accuracy: 0.5563
#
# Epoch 00035: val_loss did not improve from 1.18606
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 36/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.1057 - accuracy: 0.5836 - val_loss: 1.2236 - val_accuracy: 0.5435
#
# Epoch 00036: val_loss did not improve from 1.18606
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 37/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.0867 - accuracy: 0.5922 - val_loss: 1.3736 - val_accuracy: 0.4828
#
# Epoch 00037: val_loss did not improve from 1.18606
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 38/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.0723 - accuracy: 0.5896 - val_loss: 1.1936 - val_accuracy: 0.5628
#
# Epoch 00038: val_loss did not improve from 1.18606
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 39/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.0383 - accuracy: 0.6083 - val_loss: 1.1823 - val_accuracy: 0.5754
#
# Epoch 00039: val_loss improved from 1.18606 to 1.18231, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 40/100
# 404/404 [==============================] - 25s 63ms/step - loss: 1.0297 - accuracy: 0.6204 - val_loss: 1.2836 - val_accuracy: 0.5472
#
# Epoch 00040: val_loss did not improve from 1.18231
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 41/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.9994 - accuracy: 0.6272 - val_loss: 1.2232 - val_accuracy: 0.5690
#
# Epoch 00041: val_loss did not improve from 1.18231
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 42/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.9895 - accuracy: 0.6330 - val_loss: 1.1835 - val_accuracy: 0.5831
#
# Epoch 00042: val_loss did not improve from 1.18231
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 43/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.9478 - accuracy: 0.6496 - val_loss: 1.1666 - val_accuracy: 0.5895
#
# Epoch 00043: val_loss improved from 1.18231 to 1.16663, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 44/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.9396 - accuracy: 0.6564 - val_loss: 1.1735 - val_accuracy: 0.5969
#
# Epoch 00044: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 45/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.9221 - accuracy: 0.6609 - val_loss: 1.2298 - val_accuracy: 0.5655
#
# Epoch 00045: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 46/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.9227 - accuracy: 0.6661 - val_loss: 1.2602 - val_accuracy: 0.5757
#
# Epoch 00046: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 47/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.8704 - accuracy: 0.6787 - val_loss: 1.2089 - val_accuracy: 0.5946
#
# Epoch 00047: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 48/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.8669 - accuracy: 0.6856 - val_loss: 1.2353 - val_accuracy: 0.6012
#
# Epoch 00048: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 49/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.8467 - accuracy: 0.6952 - val_loss: 1.2549 - val_accuracy: 0.6067
#
# Epoch 00049: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 50/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.8184 - accuracy: 0.7048 - val_loss: 1.2013 - val_accuracy: 0.6084
#
# Epoch 00050: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 51/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.7874 - accuracy: 0.7167 - val_loss: 1.2575 - val_accuracy: 0.6043
#
# Epoch 00051: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 52/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.7888 - accuracy: 0.7252 - val_loss: 1.2505 - val_accuracy: 0.6094
#
# Epoch 00052: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 53/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.7773 - accuracy: 0.7215 - val_loss: 1.3127 - val_accuracy: 0.6115
#
# Epoch 00053: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 54/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.7336 - accuracy: 0.7377 - val_loss: 1.2798 - val_accuracy: 0.6153
#
# Epoch 00054: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 55/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.7263 - accuracy: 0.7436 - val_loss: 1.3622 - val_accuracy: 0.6082
#
# Epoch 00055: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 56/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.7186 - accuracy: 0.7472 - val_loss: 1.3645 - val_accuracy: 0.6184
#
# Epoch 00056: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 57/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.6927 - accuracy: 0.7560 - val_loss: 1.3800 - val_accuracy: 0.6243
#
# Epoch 00057: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 58/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.6638 - accuracy: 0.7672 - val_loss: 1.3788 - val_accuracy: 0.6166
#
# Epoch 00058: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 59/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.6467 - accuracy: 0.7783 - val_loss: 1.4478 - val_accuracy: 0.6128
#
# Epoch 00059: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 60/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.6217 - accuracy: 0.7881 - val_loss: 1.5591 - val_accuracy: 0.5898
#
# Epoch 00060: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 61/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.6091 - accuracy: 0.7860 - val_loss: 1.4487 - val_accuracy: 0.6234
#
# Epoch 00061: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 62/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.6017 - accuracy: 0.7909 - val_loss: 1.5527 - val_accuracy: 0.6183
#
# Epoch 00062: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 63/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.5892 - accuracy: 0.7984 - val_loss: 1.6103 - val_accuracy: 0.6269
#
# Epoch 00063: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 64/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.5594 - accuracy: 0.8091 - val_loss: 1.5264 - val_accuracy: 0.6093
#
# Epoch 00064: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 65/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.5488 - accuracy: 0.8092 - val_loss: 1.5232 - val_accuracy: 0.6296
#
# Epoch 00065: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 66/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.5420 - accuracy: 0.8118 - val_loss: 1.6076 - val_accuracy: 0.6224
#
# Epoch 00066: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 67/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.5286 - accuracy: 0.8153 - val_loss: 1.6456 - val_accuracy: 0.6176
#
# Epoch 00067: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 68/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.5182 - accuracy: 0.8205 - val_loss: 1.8383 - val_accuracy: 0.6153
#
# Epoch 00068: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 69/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.4995 - accuracy: 0.8277 - val_loss: 1.7239 - val_accuracy: 0.6310
#
# Epoch 00069: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 70/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.4780 - accuracy: 0.8380 - val_loss: 1.7637 - val_accuracy: 0.6289
#
# Epoch 00070: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 71/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.4834 - accuracy: 0.8376 - val_loss: 1.6705 - val_accuracy: 0.6303
#
# Epoch 00071: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 72/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.4629 - accuracy: 0.8433 - val_loss: 1.8148 - val_accuracy: 0.6310
#
# Epoch 00072: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 73/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.4476 - accuracy: 0.8439 - val_loss: 1.8872 - val_accuracy: 0.6322
#
# Epoch 00073: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 74/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.4534 - accuracy: 0.8468 - val_loss: 1.8359 - val_accuracy: 0.6362
#
# Epoch 00074: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 75/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.4256 - accuracy: 0.8568 - val_loss: 1.9876 - val_accuracy: 0.6351
#
# Epoch 00075: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 76/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.4235 - accuracy: 0.8566 - val_loss: 1.7427 - val_accuracy: 0.6300
#
# Epoch 00076: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 77/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.4067 - accuracy: 0.8599 - val_loss: 1.8709 - val_accuracy: 0.6392
#
# Epoch 00077: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 78/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3933 - accuracy: 0.8678 - val_loss: 1.8910 - val_accuracy: 0.6337
#
# Epoch 00078: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 79/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3949 - accuracy: 0.8687 - val_loss: 1.9062 - val_accuracy: 0.6390
#
# Epoch 00079: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 80/100
# 404/404 [==============================] - 26s 63ms/step - loss: 0.3757 - accuracy: 0.8726 - val_loss: 1.9662 - val_accuracy: 0.6367
#
# Epoch 00080: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 81/100
# 404/404 [==============================] - 26s 63ms/step - loss: 0.3888 - accuracy: 0.8725 - val_loss: 2.1686 - val_accuracy: 0.6396
#
# Epoch 00081: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 82/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3652 - accuracy: 0.8787 - val_loss: 2.0913 - val_accuracy: 0.6395
#
# Epoch 00082: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 83/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3766 - accuracy: 0.8747 - val_loss: 2.0707 - val_accuracy: 0.6406
#
# Epoch 00083: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 84/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3570 - accuracy: 0.8848 - val_loss: 2.1653 - val_accuracy: 0.6367
#
# Epoch 00084: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 85/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3470 - accuracy: 0.8823 - val_loss: 2.0769 - val_accuracy: 0.6390
#
# Epoch 00085: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 86/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3275 - accuracy: 0.8902 - val_loss: 2.0793 - val_accuracy: 0.6410
#
# Epoch 00086: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 87/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3341 - accuracy: 0.8907 - val_loss: 2.2125 - val_accuracy: 0.6420
#
# Epoch 00087: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 88/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3248 - accuracy: 0.8945 - val_loss: 2.1347 - val_accuracy: 0.6435
#
# Epoch 00088: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 89/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3184 - accuracy: 0.8974 - val_loss: 2.2318 - val_accuracy: 0.6415
#
# Epoch 00089: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 90/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3152 - accuracy: 0.8988 - val_loss: 2.1454 - val_accuracy: 0.6385
#
# Epoch 00090: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 91/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3102 - accuracy: 0.9022 - val_loss: 2.2511 - val_accuracy: 0.6457
#
# Epoch 00091: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 92/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.3055 - accuracy: 0.9019 - val_loss: 2.2440 - val_accuracy: 0.6392
#
# Epoch 00092: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 93/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.2893 - accuracy: 0.9084 - val_loss: 2.4179 - val_accuracy: 0.6458
#
# Epoch 00093: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 94/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.2939 - accuracy: 0.9075 - val_loss: 2.4016 - val_accuracy: 0.6427
#
# Epoch 00094: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 95/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.2841 - accuracy: 0.9092 - val_loss: 2.3280 - val_accuracy: 0.6421
#
# Epoch 00095: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 96/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.2820 - accuracy: 0.9091 - val_loss: 2.4349 - val_accuracy: 0.6440
#
# Epoch 00096: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 97/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.2705 - accuracy: 0.9112 - val_loss: 2.3193 - val_accuracy: 0.6441
#
# Epoch 00097: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 98/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.2709 - accuracy: 0.9134 - val_loss: 2.4682 - val_accuracy: 0.6440
#
# Epoch 00098: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 99/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.2737 - accuracy: 0.9110 - val_loss: 2.2952 - val_accuracy: 0.6444
#
# Epoch 00099: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 100/100
# 404/404 [==============================] - 25s 63ms/step - loss: 0.2599 - accuracy: 0.9179 - val_loss: 2.4203 - val_accuracy: 0.6474
#
# Epoch 00100: val_loss did not improve from 1.16663
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr

# %% [markdown]
# #Test the Model

# %%
predicted_test_labels = np.argmax(model.predict(test_data), axis=1)
test_labels = np.argmax(test_labels, axis=1)
print ("Accuracy score = ", accuracy_score(test_labels, predicted_test_labels))
# Out:
# Accuracy score =  0.6478127612148231

# %% [markdown]
# #Save the Model

# %%
from keras.models import model_from_json
model_json = model.to_json()
with open("/content/gdrive/My Drive/DataSets/FER2013/Original/Trained/model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("/content/gdrive/My Drive/DataSets/FER2013/Original/Trained/model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
import torch
torch.cuda.get_device_name(0)
# !nvidia-smi
# Out:
# Wed Mar  3 23:09:24 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0    32W /  70W |   4928MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
