# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import random
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras.models import Sequential #Initialise our neural network model as a sequential network
from keras.layers import Conv2D #Convolution operation
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.layers import Activation#Applies activation function
from keras.layers import Dropout#Prevents overfitting by randomly converting few outputs to zero
from keras.layers import MaxPooling2D # Maxpooling function
from keras.layers import Flatten # Converting 2D arrays into a 1D linear vector
from keras.layers import Dense # Regular fully connected neural network
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, TensorBoard, ModelCheckpoint
from sklearn.metrics import accuracy_score

# %% [markdown]
# #Preprocessing CK+

# %%
  
  
# create data and label for CK+
#  0=anger 1=disgust, 2=fear, 3=happy, 4=sadness, 5=surprise, 6=contempt
# contain 135,177,75,207,84,249,54 images

import csv
import os
import numpy as np
import h5py
import skimage.io

ck_path = '/content/gdrive/My Drive/DataSets/CK+48'

anger_path = os.path.join(ck_path, 'anger')
disgust_path = os.path.join(ck_path, 'disgust')
fear_path = os.path.join(ck_path, 'fear')
happy_path = os.path.join(ck_path, 'happy')
sadness_path = os.path.join(ck_path, 'sadness')
surprise_path = os.path.join(ck_path, 'surprise')
contempt_path = os.path.join(ck_path, 'contempt')

# # Creat the list to store the data and label information
data_x = []
data_y = []

anger = [1, 0, 0, 0, 0, 0, 0]
disgust = [0, 1, 0, 0, 0, 0, 0]
fear = [0, 0, 1, 0, 0, 0, 0]
happy = [0, 0, 0, 1, 0, 0, 0]
sadness = [0, 0, 0, 0, 1, 0, 0]
surprise = [0, 0, 0, 0, 0, 1, 0]
contempt = [0, 0, 0, 0, 0, 0, 1]

datapath = os.path.join('data','/content/gdrive/My Drive/DataSets/CK+48/CK_data.h5')
if not os.path.exists(os.path.dirname(datapath)):
    os.makedirs(os.path.dirname(datapath))

# order the file, so the training set will not contain the test set (don't random)
files = os.listdir(anger_path)
files.sort()
for filename in files:
    I = skimage.io.imread(os.path.join(anger_path,filename))
    data_x.append(I.tolist())
    data_y.append(anger)

files = os.listdir(disgust_path)
files.sort()
for filename in files:
    I = skimage.io.imread(os.path.join(disgust_path,filename))
    data_x.append(I.tolist())
    data_y.append(disgust)

files = os.listdir(fear_path)
files.sort()
for filename in files:
    I = skimage.io.imread(os.path.join(fear_path,filename))
    data_x.append(I.tolist())
    data_y.append(fear)

files = os.listdir(happy_path)
files.sort()
for filename in files:
    I = skimage.io.imread(os.path.join(happy_path,filename))
    data_x.append(I.tolist())
    data_y.append(happy)

files = os.listdir(sadness_path)
files.sort()
for filename in files:
    I = skimage.io.imread(os.path.join(sadness_path,filename))
    data_x.append(I.tolist())
    data_y.append(sadness)

files = os.listdir(surprise_path)
files.sort()
for filename in files:
    I = skimage.io.imread(os.path.join(surprise_path,filename))
    data_x.append(I.tolist())
    data_y.append(surprise)

files = os.listdir(contempt_path)
files.sort()
for filename in files:
    I = skimage.io.imread(os.path.join(contempt_path,filename))
    data_x.append(I.tolist())
    data_y.append(contempt)

data_x = np.expand_dims(data_x, -1)
print(np.shape(data_x))
print(np.shape(data_y))

print("Save data finish!!!")
# Out:
# (981, 48, 48, 1)
# (981, 7)
# Save data finish!!!

# %% [markdown]
# #Genarate random index for creating test and train data

# %%
trainSMP = random.sample(range(0, 981), 800)
print(len(trainSMP))
testSMP = [x for x in list(range(0, 981)) if x not in trainSMP ]
print(len(testSMP))
# Out:
# 800
# 181

# %% [markdown]
# #Create train and test data

# %%
train_data = np.array(data_x/255.0)
test_data = train_data[testSMP[:]]
train_data = train_data[trainSMP[:]]

train_labels = np.array(data_y)
test_labels = train_labels[testSMP[:]]
train_labels = train_labels[trainSMP[:]]
print(train_data.shape)
print(test_data.shape)
# Out:
# (800, 48, 48, 1)
# (181, 48, 48, 1)

# %% [markdown]
# #Training

# %%
#######HYPERPARAMATERS###########
epochs = 100
batch_size = 16
learning_rate = 0.001
#################################

model = Sequential()
    
model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1), kernel_regularizer=l2(0.01)))
model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
adam = optimizers.Adam(lr = learning_rate)
model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
print(model.summary())

lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3)
early_stopper = EarlyStopping(monitor='val_acc', min_delta=0, patience=6, mode='auto')
checkpointer = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5', monitor='val_loss', verbose=1, save_best_only=True)

model.fit(
          train_data,
          train_labels,
          epochs = epochs,
          batch_size = batch_size,
          validation_split = 0.2,
          shuffle = True,
          callbacks=[lr_reducer, checkpointer, early_stopper]
          )
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_114 (Conv2D)          (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_115 (Conv2D)          (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization_107 (Bat (None, 46, 46, 64)        256
# _________________________________________________________________
# conv2d_116 (Conv2D)          (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization_108 (Bat (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_64 (Dropout)         (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_109 (Bat (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_110 (Bat (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_111 (Bat (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_65 (Dropout)         (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_120 (Conv2D)          (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_112 (Bat (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_113 (Bat (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_114 (Bat (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_123 (Conv2D)          (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_115 (Bat (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_124 (Conv2D)          (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_116 (Bat (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_125 (Conv2D)          (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_117 (Bat (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_126 (Conv2D)          (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_118 (Bat (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_127 (Conv2D)          (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_119 (Bat (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_40 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_44 (Dense)             (None, 7)                 455
# =================================================================
# Total params: 13,775,623
# Trainable params: 13,767,943
# Non-trainable params: 7,680
# _________________________________________________________________
# None
# Epoch 1/100
# 40/40 [==============================] - 3s 46ms/step - loss: 5.4720 - accuracy: 0.1645 - val_loss: 1.9535 - val_accuracy: 0.2562
#
# Epoch 00001: val_loss improved from inf to 1.95346, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 2/100
# 40/40 [==============================] - 1s 36ms/step - loss: 3.1810 - accuracy: 0.1470 - val_loss: 1.9497 - val_accuracy: 0.1375
#
# Epoch 00002: val_loss improved from 1.95346 to 1.94967, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 3/100
# 40/40 [==============================] - 1s 36ms/step - loss: 2.4244 - accuracy: 0.1941 - val_loss: 1.9640 - val_accuracy: 0.1813
#
# Epoch 00003: val_loss did not improve from 1.94967
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 4/100
# 40/40 [==============================] - 1s 36ms/step - loss: 2.2874 - accuracy: 0.2036 - val_loss: 1.9015 - val_accuracy: 0.1312
#
# Epoch 00004: val_loss improved from 1.94967 to 1.90145, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 5/100
# 40/40 [==============================] - 1s 37ms/step - loss: 2.0945 - accuracy: 0.1771 - val_loss: 1.9345 - val_accuracy: 0.2812
#
# Epoch 00005: val_loss did not improve from 1.90145
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 6/100
# 40/40 [==============================] - 1s 36ms/step - loss: 2.0387 - accuracy: 0.2199 - val_loss: 1.9107 - val_accuracy: 0.2812
#
# Epoch 00006: val_loss did not improve from 1.90145
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 7/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.9937 - accuracy: 0.2242 - val_loss: 1.9197 - val_accuracy: 0.1813
#
# Epoch 00007: val_loss did not improve from 1.90145
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 8/100
# 40/40 [==============================] - 1s 36ms/step - loss: 2.0071 - accuracy: 0.1727 - val_loss: 1.9219 - val_accuracy: 0.2750
#
# Epoch 00008: val_loss did not improve from 1.90145
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 9/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.9610 - accuracy: 0.2042 - val_loss: 1.9095 - val_accuracy: 0.2812
#
# Epoch 00009: val_loss did not improve from 1.90145
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 10/100
# 40/40 [==============================] - 1s 37ms/step - loss: 2.0189 - accuracy: 0.2050 - val_loss: 1.9115 - val_accuracy: 0.2812
#
# Epoch 00010: val_loss did not improve from 1.90145
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 11/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8983 - accuracy: 0.2302 - val_loss: 1.8854 - val_accuracy: 0.2875
#
# Epoch 00011: val_loss improved from 1.90145 to 1.88540, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 12/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.9618 - accuracy: 0.2154 - val_loss: 1.8996 - val_accuracy: 0.2000
#
# Epoch 00012: val_loss did not improve from 1.88540
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 13/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.9059 - accuracy: 0.2361 - val_loss: 1.8740 - val_accuracy: 0.2625
#
# Epoch 00013: val_loss improved from 1.88540 to 1.87397, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 14/100
# 40/40 [==============================] - 2s 38ms/step - loss: 1.8765 - accuracy: 0.2260 - val_loss: 1.8849 - val_accuracy: 0.2812
#
# Epoch 00014: val_loss did not improve from 1.87397
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 15/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.9249 - accuracy: 0.2088 - val_loss: 1.8792 - val_accuracy: 0.2812
#
# Epoch 00015: val_loss did not improve from 1.87397
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 16/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8929 - accuracy: 0.2610 - val_loss: 1.8684 - val_accuracy: 0.1875
#
# Epoch 00016: val_loss improved from 1.87397 to 1.86838, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 17/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.9060 - accuracy: 0.2336 - val_loss: 1.8923 - val_accuracy: 0.1813
#
# Epoch 00017: val_loss did not improve from 1.86838
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 18/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8512 - accuracy: 0.2436 - val_loss: 1.8988 - val_accuracy: 0.2812
#
# Epoch 00018: val_loss did not improve from 1.86838
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 19/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8803 - accuracy: 0.2538 - val_loss: 1.8769 - val_accuracy: 0.2812
#
# Epoch 00019: val_loss did not improve from 1.86838
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 20/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8926 - accuracy: 0.2403 - val_loss: 1.8915 - val_accuracy: 0.2812
#
# Epoch 00020: val_loss did not improve from 1.86838
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 21/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8707 - accuracy: 0.2150 - val_loss: 1.8739 - val_accuracy: 0.2812
#
# Epoch 00021: val_loss did not improve from 1.86838
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 22/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8648 - accuracy: 0.2733 - val_loss: 1.8699 - val_accuracy: 0.2937
#
# Epoch 00022: val_loss did not improve from 1.86838
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 23/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8353 - accuracy: 0.2682 - val_loss: 1.8712 - val_accuracy: 0.2875
#
# Epoch 00023: val_loss did not improve from 1.86838
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 24/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.8580 - accuracy: 0.2549 - val_loss: 1.8568 - val_accuracy: 0.2125
#
# Epoch 00024: val_loss improved from 1.86838 to 1.85681, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 25/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.8314 - accuracy: 0.2433 - val_loss: 1.8620 - val_accuracy: 0.2812
#
# Epoch 00025: val_loss did not improve from 1.85681
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 26/100
# 40/40 [==============================] - 1s 35ms/step - loss: 1.8487 - accuracy: 0.2181 - val_loss: 1.8655 - val_accuracy: 0.2812
#
# Epoch 00026: val_loss did not improve from 1.85681
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 27/100
# 40/40 [==============================] - 1s 35ms/step - loss: 1.8602 - accuracy: 0.2461 - val_loss: 1.8732 - val_accuracy: 0.2812
#
# Epoch 00027: val_loss did not improve from 1.85681
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 28/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8286 - accuracy: 0.2626 - val_loss: 1.8671 - val_accuracy: 0.2812
#
# Epoch 00028: val_loss did not improve from 1.85681
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 29/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8472 - accuracy: 0.2331 - val_loss: 1.8584 - val_accuracy: 0.2875
#
# Epoch 00029: val_loss did not improve from 1.85681
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 30/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8589 - accuracy: 0.2371 - val_loss: 1.8475 - val_accuracy: 0.3250
#
# Epoch 00030: val_loss improved from 1.85681 to 1.84752, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 31/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.8063 - accuracy: 0.2583 - val_loss: 1.8544 - val_accuracy: 0.3063
#
# Epoch 00031: val_loss did not improve from 1.84752
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 32/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8643 - accuracy: 0.2283 - val_loss: 1.8664 - val_accuracy: 0.2812
#
# Epoch 00032: val_loss did not improve from 1.84752
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 33/100
# 40/40 [==============================] - 1s 35ms/step - loss: 1.8549 - accuracy: 0.2711 - val_loss: 1.8392 - val_accuracy: 0.3000
#
# Epoch 00033: val_loss improved from 1.84752 to 1.83923, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 34/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.8501 - accuracy: 0.2757 - val_loss: 1.8426 - val_accuracy: 0.2812
#
# Epoch 00034: val_loss did not improve from 1.83923
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 35/100
# 40/40 [==============================] - 1s 35ms/step - loss: 1.8241 - accuracy: 0.2306 - val_loss: 1.8368 - val_accuracy: 0.3000
#
# Epoch 00035: val_loss improved from 1.83923 to 1.83679, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 36/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.8219 - accuracy: 0.2588 - val_loss: 1.8302 - val_accuracy: 0.3063
#
# Epoch 00036: val_loss improved from 1.83679 to 1.83019, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 37/100
# 40/40 [==============================] - 2s 38ms/step - loss: 1.8281 - accuracy: 0.2534 - val_loss: 1.8457 - val_accuracy: 0.2812
#
# Epoch 00037: val_loss did not improve from 1.83019
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 38/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8134 - accuracy: 0.2439 - val_loss: 1.8271 - val_accuracy: 0.2875
#
# Epoch 00038: val_loss improved from 1.83019 to 1.82711, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 39/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.8106 - accuracy: 0.2726 - val_loss: 1.8021 - val_accuracy: 0.3000
#
# Epoch 00039: val_loss improved from 1.82711 to 1.80205, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 40/100
# 40/40 [==============================] - 2s 38ms/step - loss: 1.7617 - accuracy: 0.2628 - val_loss: 1.8293 - val_accuracy: 0.2875
#
# Epoch 00040: val_loss did not improve from 1.80205
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 41/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.7774 - accuracy: 0.2774 - val_loss: 1.7993 - val_accuracy: 0.3375
#
# Epoch 00041: val_loss improved from 1.80205 to 1.79929, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 42/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.7625 - accuracy: 0.2972 - val_loss: 1.8796 - val_accuracy: 0.3125
#
# Epoch 00042: val_loss did not improve from 1.79929
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 43/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.7305 - accuracy: 0.3088 - val_loss: 1.8545 - val_accuracy: 0.1813
#
# Epoch 00043: val_loss did not improve from 1.79929
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 44/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.8285 - accuracy: 0.2810 - val_loss: 1.8370 - val_accuracy: 0.3187
#
# Epoch 00044: val_loss did not improve from 1.79929
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 45/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.7232 - accuracy: 0.3460 - val_loss: 1.8344 - val_accuracy: 0.2500
#
# Epoch 00045: val_loss did not improve from 1.79929
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 46/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.6804 - accuracy: 0.3371 - val_loss: 1.7553 - val_accuracy: 0.3313
#
# Epoch 00046: val_loss improved from 1.79929 to 1.75528, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 47/100
# 40/40 [==============================] - 2s 37ms/step - loss: 1.7475 - accuracy: 0.3037 - val_loss: 1.7693 - val_accuracy: 0.2812
#
# Epoch 00047: val_loss did not improve from 1.75528
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 48/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.7207 - accuracy: 0.2489 - val_loss: 1.7140 - val_accuracy: 0.2688
#
# Epoch 00048: val_loss improved from 1.75528 to 1.71396, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 49/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.6437 - accuracy: 0.2865 - val_loss: 1.5773 - val_accuracy: 0.3000
#
# Epoch 00049: val_loss improved from 1.71396 to 1.57731, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 50/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.6493 - accuracy: 0.2888 - val_loss: 1.6917 - val_accuracy: 0.3688
#
# Epoch 00050: val_loss did not improve from 1.57731
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 51/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.5861 - accuracy: 0.3216 - val_loss: 1.3991 - val_accuracy: 0.4062
#
# Epoch 00051: val_loss improved from 1.57731 to 1.39911, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 52/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.5966 - accuracy: 0.3557 - val_loss: 1.3644 - val_accuracy: 0.3938
#
# Epoch 00052: val_loss improved from 1.39911 to 1.36436, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 53/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.5202 - accuracy: 0.3631 - val_loss: 1.3226 - val_accuracy: 0.3688
#
# Epoch 00053: val_loss improved from 1.36436 to 1.32257, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 54/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.4508 - accuracy: 0.3762 - val_loss: 1.2907 - val_accuracy: 0.4125
#
# Epoch 00054: val_loss improved from 1.32257 to 1.29075, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 55/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.3519 - accuracy: 0.4172 - val_loss: 1.2933 - val_accuracy: 0.4437
#
# Epoch 00055: val_loss did not improve from 1.29075
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 56/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.3952 - accuracy: 0.4247 - val_loss: 1.1893 - val_accuracy: 0.4625
#
# Epoch 00056: val_loss improved from 1.29075 to 1.18926, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 57/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.2795 - accuracy: 0.4426 - val_loss: 1.2527 - val_accuracy: 0.4125
#
# Epoch 00057: val_loss did not improve from 1.18926
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 58/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.2409 - accuracy: 0.4938 - val_loss: 1.2490 - val_accuracy: 0.5875
#
# Epoch 00058: val_loss did not improve from 1.18926
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 59/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.2268 - accuracy: 0.5094 - val_loss: 1.5521 - val_accuracy: 0.5625
#
# Epoch 00059: val_loss did not improve from 1.18926
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 60/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.1944 - accuracy: 0.5445 - val_loss: 1.1149 - val_accuracy: 0.5750
#
# Epoch 00060: val_loss improved from 1.18926 to 1.11486, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 61/100
# 40/40 [==============================] - 2s 38ms/step - loss: 1.0916 - accuracy: 0.6032 - val_loss: 1.3176 - val_accuracy: 0.5250
#
# Epoch 00061: val_loss did not improve from 1.11486
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 62/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.1864 - accuracy: 0.5554 - val_loss: 1.1194 - val_accuracy: 0.5813
#
# Epoch 00062: val_loss did not improve from 1.11486
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 63/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.1575 - accuracy: 0.5740 - val_loss: 1.0185 - val_accuracy: 0.5938
#
# Epoch 00063: val_loss improved from 1.11486 to 1.01851, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 64/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.0923 - accuracy: 0.5787 - val_loss: 1.1546 - val_accuracy: 0.5813
#
# Epoch 00064: val_loss did not improve from 1.01851
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 65/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.0497 - accuracy: 0.6298 - val_loss: 0.9551 - val_accuracy: 0.6062
#
# Epoch 00065: val_loss improved from 1.01851 to 0.95512, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 66/100
# 40/40 [==============================] - 2s 38ms/step - loss: 1.0326 - accuracy: 0.5834 - val_loss: 0.9298 - val_accuracy: 0.6250
#
# Epoch 00066: val_loss improved from 0.95512 to 0.92980, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 67/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.9905 - accuracy: 0.6440 - val_loss: 0.8997 - val_accuracy: 0.6062
#
# Epoch 00067: val_loss improved from 0.92980 to 0.89973, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 68/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.9406 - accuracy: 0.6547 - val_loss: 1.1993 - val_accuracy: 0.5688
#
# Epoch 00068: val_loss did not improve from 0.89973
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 69/100
# 40/40 [==============================] - 1s 36ms/step - loss: 1.1253 - accuracy: 0.5942 - val_loss: 0.9972 - val_accuracy: 0.5437
#
# Epoch 00069: val_loss did not improve from 0.89973
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 70/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.8907 - accuracy: 0.6407 - val_loss: 0.8293 - val_accuracy: 0.6313
#
# Epoch 00070: val_loss improved from 0.89973 to 0.82934, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 71/100
# 40/40 [==============================] - 2s 38ms/step - loss: 0.9475 - accuracy: 0.5913 - val_loss: 0.9154 - val_accuracy: 0.6313
#
# Epoch 00071: val_loss did not improve from 0.82934
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 72/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.9870 - accuracy: 0.6102 - val_loss: 1.6887 - val_accuracy: 0.5125
#
# Epoch 00072: val_loss did not improve from 0.82934
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 73/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.9714 - accuracy: 0.6127 - val_loss: 0.9194 - val_accuracy: 0.6125
#
# Epoch 00073: val_loss did not improve from 0.82934
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 74/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.9565 - accuracy: 0.6259 - val_loss: 1.0237 - val_accuracy: 0.6313
#
# Epoch 00074: val_loss did not improve from 0.82934
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 75/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.9038 - accuracy: 0.6444 - val_loss: 1.1704 - val_accuracy: 0.4812
#
# Epoch 00075: val_loss did not improve from 0.82934
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 76/100
# 40/40 [==============================] - 1s 37ms/step - loss: 1.1250 - accuracy: 0.5728 - val_loss: 0.9637 - val_accuracy: 0.5813
#
# Epoch 00076: val_loss did not improve from 0.82934
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 77/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.8930 - accuracy: 0.6093 - val_loss: 0.7951 - val_accuracy: 0.6375
#
# Epoch 00077: val_loss improved from 0.82934 to 0.79511, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 78/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.8156 - accuracy: 0.6515 - val_loss: 0.7778 - val_accuracy: 0.6313
#
# Epoch 00078: val_loss improved from 0.79511 to 0.77778, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 79/100
# 40/40 [==============================] - 2s 38ms/step - loss: 0.8819 - accuracy: 0.6103 - val_loss: 0.9063 - val_accuracy: 0.6187
#
# Epoch 00079: val_loss did not improve from 0.77778
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 80/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.8354 - accuracy: 0.6292 - val_loss: 0.9897 - val_accuracy: 0.5813
#
# Epoch 00080: val_loss did not improve from 0.77778
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 81/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.8201 - accuracy: 0.6205 - val_loss: 0.8497 - val_accuracy: 0.6125
#
# Epoch 00081: val_loss did not improve from 0.77778
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 82/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.7910 - accuracy: 0.6603 - val_loss: 0.7756 - val_accuracy: 0.6375
#
# Epoch 00082: val_loss improved from 0.77778 to 0.77563, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 83/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.8075 - accuracy: 0.6348 - val_loss: 0.8112 - val_accuracy: 0.6438
#
# Epoch 00083: val_loss did not improve from 0.77563
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 84/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.7967 - accuracy: 0.6238 - val_loss: 0.8161 - val_accuracy: 0.6375
#
# Epoch 00084: val_loss did not improve from 0.77563
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 85/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.7289 - accuracy: 0.6571 - val_loss: 0.8691 - val_accuracy: 0.6313
#
# Epoch 00085: val_loss did not improve from 0.77563
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 86/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.7019 - accuracy: 0.6593 - val_loss: 0.8664 - val_accuracy: 0.6375
#
# Epoch 00086: val_loss did not improve from 0.77563
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 87/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.8004 - accuracy: 0.6319 - val_loss: 0.8670 - val_accuracy: 0.6313
#
# Epoch 00087: val_loss did not improve from 0.77563
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 88/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.7647 - accuracy: 0.6368 - val_loss: 0.8723 - val_accuracy: 0.6375
#
# Epoch 00088: val_loss did not improve from 0.77563
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 89/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.7396 - accuracy: 0.6515 - val_loss: 0.8750 - val_accuracy: 0.6000
#
# Epoch 00089: val_loss did not improve from 0.77563
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 90/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.7617 - accuracy: 0.6464 - val_loss: 0.7812 - val_accuracy: 0.6375
#
# Epoch 00090: val_loss did not improve from 0.77563
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 91/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.6861 - accuracy: 0.6679 - val_loss: 0.7259 - val_accuracy: 0.6438
#
# Epoch 00091: val_loss improved from 0.77563 to 0.72591, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 92/100
# 40/40 [==============================] - 2s 37ms/step - loss: 0.7210 - accuracy: 0.6547 - val_loss: 0.7436 - val_accuracy: 0.6438
#
# Epoch 00092: val_loss did not improve from 0.72591
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 93/100
# 40/40 [==============================] - 1s 37ms/step - loss: 0.7641 - accuracy: 0.6635 - val_loss: 0.8340 - val_accuracy: 0.6187
#
# Epoch 00093: val_loss did not improve from 0.72591
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 94/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.7379 - accuracy: 0.6643 - val_loss: 0.7304 - val_accuracy: 0.6313
#
# Epoch 00094: val_loss did not improve from 0.72591
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 95/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.7463 - accuracy: 0.6268 - val_loss: 0.6886 - val_accuracy: 0.6375
#
# Epoch 00095: val_loss improved from 0.72591 to 0.68860, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 96/100
# 40/40 [==============================] - 2s 37ms/step - loss: 0.6599 - accuracy: 0.6884 - val_loss: 0.7207 - val_accuracy: 0.6250
#
# Epoch 00096: val_loss did not improve from 0.68860
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 97/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.6000 - accuracy: 0.6804 - val_loss: 0.6966 - val_accuracy: 0.6313
#
# Epoch 00097: val_loss did not improve from 0.68860
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 98/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.6863 - accuracy: 0.6508 - val_loss: 0.7060 - val_accuracy: 0.6313
#
# Epoch 00098: val_loss did not improve from 0.68860
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 99/100
# 40/40 [==============================] - 1s 36ms/step - loss: 0.6334 - accuracy: 0.6619 - val_loss: 0.6814 - val_accuracy: 0.6313
#
# Epoch 00099: val_loss improved from 0.68860 to 0.68136, saving model to /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Model/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 100/100
# 40/40 [==============================] - 2s 38ms/step - loss: 0.6346 - accuracy: 0.6692 - val_loss: 0.7083 - val_accuracy: 0.6313
#
# Epoch 00100: val_loss did not improve from 0.68136
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr

# %%
predicted_test_labels = np.argmax(model.predict(test_data), axis=1)
test_labels = np.argmax(test_labels, axis=1)
print ("Accuracy score = ", accuracy_score(test_labels, predicted_test_labels))
# Out:
# Accuracy score =  0.5580110497237569

# %% [markdown]
# #Save the Model

# %%
from keras.models import model_from_json
model_json = model.to_json()
with open("/content/gdrive/My Drive/DataSets/CK+48/Trained/model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("/content/gdrive/My Drive/DataSets/CK+48/Trained/model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
